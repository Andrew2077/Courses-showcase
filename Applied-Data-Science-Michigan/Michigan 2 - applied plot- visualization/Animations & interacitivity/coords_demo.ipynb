# %%
# %matplotlib widget
import matplotlib
matplotlib.interactive(True)
matplotlib.is_interactive()
# Out:
# True

# %% [markdown]
# # Mouse move and click events
#
# An example of how to interact with the plotting canvas by connecting to move
# and click events.

# %%
from matplotlib.backend_bases import MouseButton
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 1.0, 0.01)
s = np.sin(2 * np.pi * t)
fig, ax = plt.subplots()
ax.plot(t, s)


def on_move(event):
    # get the x and y pixel coords
    x, y = event.x, event.y
    if event.inaxes:
        ax = event.inaxes  # the axes instance
        print('data coords %f %f' % (event.xdata, event.ydata))


def on_click(event):
    if event.button is MouseButton.LEFT:
        print('disconnecting callback')
        plt.disconnect(binding_id)


binding_id = plt.connect('motion_notify_event', on_move)
plt.connect('button_press_event', on_click)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# data coords 0.455538 0.913807
# data coords 0.435778 0.866188
# data coords 0.361129 0.729283
# data coords 0.354542 0.705474
# data coords 0.347956 0.669759
# data coords 0.343564 0.634045
# data coords 0.343564 0.610236
# data coords 0.343564 0.592378
# data coords 0.343564 0.580474
# data coords 0.347956 0.568569
# data coords 0.361129 0.556664
# data coords 0.391867 0.538807
# data coords 0.409431 0.532855
# data coords 0.418214 0.532855
# data coords 0.422605 0.532855
# data coords 0.424800 0.520950
# data coords 0.424800 0.514997
# data coords 0.424800 0.491188
# data coords 0.422605 0.485236
# data coords 0.668508 -1.050479
# data coords 0.670704 -1.026669
# data coords 0.683877 -0.985003
# data coords 0.699246 -0.943336
# data coords 0.701441 -0.937384
# data coords 0.705833 -0.925479
# data coords 0.710224 -0.907622
# data coords 0.721202 -0.877860
# data coords 0.725593 -0.877860
# data coords 0.725593 -0.883812
# data coords 0.725593 -0.895717
# data coords 0.725593 -0.913574
# data coords 0.725593 -0.931431
# data coords 0.723397 -0.943336
# data coords 0.723397 -0.949288
# data coords 0.721202 -0.955241
# data coords 0.721202 -0.961193
# data coords 0.721202 -0.967145
# data coords 0.719006 -0.979050
# data coords 0.699246 -0.324288
# data coords 0.699246 -0.336193
# data coords 0.699246 -0.383812
# data coords 0.701441 -0.455241
# data coords 0.708028 -0.485003
# data coords 0.723397 -0.532622
# data coords 0.732179 -0.562384
# data coords 0.749744 -0.615955
# data coords 0.760722 -0.645717
# data coords 0.776091 -0.681431
# data coords 0.778286 -0.681431
# data coords 0.780482 -0.687384
# data coords 0.793655 -0.687384
# data coords 0.802437 -0.687384
# data coords 0.809024 -0.687384
# data coords 0.817806 -0.687384
# data coords 0.830980 -0.669526
# data coords 0.835371 -0.669526
# data coords 0.844153 -0.651669
# data coords 0.848544 -0.645717
# data coords 0.855131 -0.633812
# data coords 0.872695 -0.615955
# data coords 0.877087 -0.610003
# data coords 0.881478 -0.598098
# data coords 0.938562 -0.485003
# data coords 0.964909 -0.431431
# data coords 0.973691 -0.395717
# data coords 0.982474 -0.330241
# data coords 0.989060 -0.235003
# data coords 0.989060 -0.211193
# data coords 0.989060 -0.115955
# data coords 0.989060 -0.110003
# data coords 0.989060 -0.104050
# data coords 0.989060 -0.092145
# data coords 0.989060 -0.074288
# data coords 0.989060 -0.068336
# data coords 0.989060 -0.074288
# data coords 0.984669 -0.092145
# data coords 0.978083 -0.110003
# data coords 0.978083 -0.115955
# data coords 0.975887 -0.127860
# data coords 0.973691 -0.139764
# data coords 0.971496 -0.145717
# data coords 0.969300 -0.151669
# data coords 0.967105 -0.157622
# data coords 0.967105 -0.175479
# data coords 0.962714 -0.199288
# data coords 0.958322 -0.217145
# data coords 0.953931 -0.235003
# data coords 0.951736 -0.240955
# data coords 0.951736 -0.252860
# data coords 0.947345 -0.276669
# data coords 0.942954 -0.300479
# data coords 0.942954 -0.306431
# data coords 0.938562 -0.324288
# data coords 0.938562 -0.336193
# data coords 0.936367 -0.342145
# data coords 0.934171 -0.360003
# data coords 0.931976 -0.377860
# data coords 0.929780 -0.383812
# data coords 0.927585 -0.395717
# data coords 0.927585 -0.401669
# data coords 0.927585 -0.413574
# data coords 0.923193 -0.431431
# data coords 0.918802 -0.449288
# data coords 0.918802 -0.455241
# data coords 0.914411 -0.473098
# data coords 0.914411 -0.485003
# data coords 0.914411 -0.496907
# data coords 0.912216 -0.508812
# data coords 0.910020 -0.508812
# data coords 0.910020 -0.514764
# data coords 0.910020 -0.526669
# data coords 0.907824 -0.538574
# data coords 0.907824 -0.544526
# data coords 0.905629 -0.556431
# data coords 0.901238 -0.574288
# data coords 0.899042 -0.580241
# data coords 0.899042 -0.586193
# data coords 0.896847 -0.592145
# data coords 0.896847 -0.598098
# data coords 0.885869 -0.645717
# data coords 0.881478 -0.663574
# data coords 0.881478 -0.669526
# data coords 0.863913 -0.723098
# data coords 0.861718 -0.729050
# data coords 0.776091 -1.044526
# data coords 0.760722 -1.008812
# data coords 0.806829 -0.901669
# data coords 0.907824 -0.610003
# data coords 0.929780 -0.514764
# data coords 0.936367 -0.467145
# data coords 0.936367 -0.455241
# data coords 0.947345 -0.336193
# data coords 0.949540 -0.306431
# data coords 0.953931 -0.276669
# data coords 0.960518 -0.211193
# data coords 0.967105 -0.163574
# data coords 0.973691 -0.115955
# data coords 0.978083 -0.092145
# data coords 0.986865 -0.068336
# data coords 0.986865 -0.062384
# data coords 0.989060 -0.050479
# data coords 0.989060 -0.056431
# data coords 0.989060 -0.074288
# data coords 0.986865 -0.086193
# data coords 0.984669 -0.098098
# data coords 0.982474 -0.110003
# data coords 0.980278 -0.115955
# data coords 0.978083 -0.127860
# data coords 0.973691 -0.145717
# data coords 0.969300 -0.169526
# data coords 0.967105 -0.181431
# data coords 0.967105 -0.187384
# data coords 0.960518 -0.211193
# data coords 0.958322 -0.217145
# data coords 0.958322 -0.223098
# data coords 0.956127 -0.229050
# data coords 0.956127 -0.235003
# data coords 0.951736 -0.252860
# data coords 0.947345 -0.270717
# data coords 0.947345 -0.276669
# data coords 0.942954 -0.300479
# data coords 0.938562 -0.330241
# data coords 0.936367 -0.360003
# data coords 0.931976 -0.365955
# data coords 0.929780 -0.377860
# data coords 0.927585 -0.389764
# data coords 0.927585 -0.395717
# data coords 0.923193 -0.413574
# data coords 0.918802 -0.425479
# data coords 0.918802 -0.437384
# data coords 0.912216 -0.449288
# data coords 0.910020 -0.467145
# data coords 0.905629 -0.473098
# data coords 0.903433 -0.496907
# data coords 0.899042 -0.514764
# data coords 0.899042 -0.520717
# data coords 0.896847 -0.526669
# data coords 0.892456 -0.562384
# data coords 0.888064 -0.586193
# data coords 0.885869 -0.627860
# data coords 0.883673 -0.645717
# data coords 0.879282 -0.729050
# data coords 0.874891 -0.764764
# data coords 0.874891 -0.776669
# data coords 0.874891 -0.782622
# data coords 0.868304 -0.824288
# data coords 0.863913 -0.854050
# data coords 0.863913 -0.860003
# data coords 0.861718 -0.860003
# data coords 0.861718 -0.865955
# data coords 0.855131 -0.889764
# data coords 0.855131 -0.901669
# data coords 0.848544 -0.919526
# data coords 0.835371 -0.943336
# data coords 0.833175 -0.955241
# data coords 0.820002 -0.961193
# data coords 0.811220 -0.973098
# data coords 0.795851 -0.973098
# data coords 0.784873 -0.979050
# data coords 0.780482 -0.979050
# data coords 0.767308 -0.979050
# data coords 0.760722 -0.979050
# data coords 0.754135 -0.979050
# data coords 0.749744 -0.979050
# data coords 0.745353 -0.979050
# data coords 0.716810 -0.967145
# data coords 0.710224 -0.955241
# data coords 0.705833 -0.943336
# data coords 0.694855 -0.931431
# data coords 0.690464 -0.919526
# data coords 0.681681 -0.901669
# data coords 0.675095 -0.889764
# data coords 0.668508 -0.877860
# data coords 0.659726 -0.860003
# data coords 0.639966 -0.806431
# data coords 0.637770 -0.806431
# data coords 0.633379 -0.800479
# data coords 0.633379 -0.794526
# data coords 0.624597 -0.764764
# data coords 0.622401 -0.752860
# data coords 0.618010 -0.693336
# data coords 0.611423 -0.663574
# data coords 0.609228 -0.621907
# data coords 0.604837 -0.610003
# data coords 0.600445 -0.592145
# data coords 0.589468 -0.562384
# data coords 0.587272 -0.544526
# data coords 0.574099 -0.520717
# data coords 0.556534 -0.467145
# data coords 0.549947 -0.443336
# data coords 0.536774 -0.383812
# data coords 0.527992 -0.336193
# data coords 0.519210 -0.282622
# data coords 0.517014 -0.276669
# data coords 0.501645 -0.175479
# data coords 0.497254 -0.151669
# data coords 0.495058 -0.121907
# data coords 0.495058 -0.104050
# data coords 0.492863 -0.080241
# data coords 0.486276 -0.032622
# data coords 0.477494 0.020950
# data coords 0.466516 0.074521
# data coords 0.462125 0.134045
# data coords 0.455538 0.169759
# data coords 0.448952 0.193569
# data coords 0.437974 0.241188
# data coords 0.429191 0.306664
# data coords 0.424800 0.324521
# data coords 0.413822 0.384045
# data coords 0.398454 0.455474
# data coords 0.396258 0.461426
# data coords 0.376498 0.556664
# data coords 0.332587 0.639997
# data coords 0.323804 0.651902
# data coords 0.301849 0.675712
# data coords 0.233786 0.776902
# data coords 0.097661 0.759045
# data coords 0.095466 0.729283
# data coords 0.091074 0.669759
# data coords 0.073510 0.497140
# data coords 0.066923 0.443569
# data coords 0.062532 0.401902
# data coords 0.038381 0.145950
# data coords 0.038381 -0.032622
# data coords 0.071314 -0.336193
# data coords 0.077901 -0.377860
# data coords 0.082292 -0.389764
# data coords 0.086683 -0.056431
# data coords 0.088879 0.663807
# data coords 0.220613 0.544759
# data coords 0.675095 0.616188
# data coords 1.032972 0.753093
