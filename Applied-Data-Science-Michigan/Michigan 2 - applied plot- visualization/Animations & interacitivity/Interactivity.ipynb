# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib widget
import matplotlib
matplotlib.interactive(True)
matplotlib.is_interactive()
# Out:
# True

# %%
plt.figure()
data = np.random.rand(10)
plt.plot(data)


def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('event at pixels {},{} {} and data {},{}'.format(
        event.x, event.y, '\n', event.xdata, event.ydata))

plt.gcf().canvas.mpl_connect('button_press_event', onclick)
# Out:
# 12
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from random import shuffle

origins = ['Japan', 'Korea', 'America', 'Europe', 'China', 'Others']

shuffle(origins)

df = pd.DataFrame({'height': np.random.rand(len(origins)), 
                   'weight': np.random.rand(len(origins)),
                   'origin': origins}) 

df
# Out:
#      height    weight   origin
# 0  0.142919  0.983783    Japan
# 1  0.688662  0.105753   Europe
# 2  0.172573  0.063363    China
# 3  0.537384  0.454591   Others
# 4  0.362202  0.239114  America
# 5  0.887772  0.086341    Korea

# %%
plt.figure()
plt.scatter(df['height'], df['weight'] , picker=2)
plt.gca().set_ylabel('weight')
plt.gca().set_xlabel('height')

def onpick(event):
    origins = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title('selected item came from {}'.format(origins))
    
plt.gcf().canvas.mpl_connect('pick_event', onpick)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
